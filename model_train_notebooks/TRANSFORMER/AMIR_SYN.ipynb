# %% [markdown]
# <a href="https://colab.research.google.com/github/arrxy/MRI-SuperResolution/blob/main/AMIR_SYN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nilearn pytorch_msssim
# Out:
# Requirement already satisfied: nilearn in /usr/local/lib/python3.12/dist-packages (0.13.1)
# Requirement already satisfied: pytorch_msssim in /usr/local/lib/python3.12/dist-packages (1.0.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from nilearn) (3.1.6)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from nilearn) (1.5.3)
# Requirement already satisfied: nibabel>=5.2.0 in /usr/local/lib/python3.12/dist-packages (from nilearn) (5.3.3)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.12/dist-packages (from nilearn) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from nilearn) (26.0)
# Requirement already satisfied: pandas>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from nilearn) (2.2.2)
# Requirement already satisfied: requests>=2.30.0 in /usr/local/lib/python3.12/dist-packages (from nilearn) (2.32.4)
# Requirement already satisfied: scikit-learn>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from nilearn) (1.6.1)
# Requirement already satisfied: scipy>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from nilearn) (1.16.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from pytorch_msssim) (2.9.0+cu128)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=3.1.2->nilearn) (3.0.3)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.12/dist-packages (from nibabel>=5.2.0->nilearn) (4.15.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->nilearn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->nilearn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->nilearn) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->nilearn) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->nilearn) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->nilearn) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->nilearn) (2026.1.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.0->nilearn) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->pytorch_msssim) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->pytorch_msssim) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch_msssim) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch_msssim) (3.6.1)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch_msssim) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch_msssim) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch_msssim) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch_msssim) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch_msssim) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch_msssim) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch_msssim) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch_msssim) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch_msssim) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch_msssim) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch_msssim) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch_msssim) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch_msssim) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch_msssim) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch_msssim) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch_msssim) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch_msssim) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2.0->nilearn) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->pytorch_msssim) (1.3.0)

# %%
import cv2
import pdb
import os
import pandas as pd
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt
import scipy.ndimage as ndimage
import ipywidgets as widgets
import scipy.signal, scipy.misc
import plotly.graph_objects as go
import random
import base64
import io

from ipywidgets import interact, IntSlider, FloatSlider
from nilearn.maskers import NiftiLabelsMasker
from nilearn.interfaces.fmriprep import load_confounds
from nilearn import plotting, datasets, image, regions
from nilearn.connectome import ConnectivityMeasure
from nilearn.decoding import Decoder
from nilearn.image import mean_img, index_img
from nilearn.datasets import MNI152_FILE_PATH, load_mni152_template
from nilearn.interfaces.fmriprep import load_confounds_strategy
from nilearn.plotting import plot_glass_brain, view_img_on_surf, plot_epi, show, plot_roi, view_img
from nibabel.testing import data_path
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import Image
from sklearn.model_selection import LeaveOneGroupOut
from skimage import data
from skimage.color import rgb2gray
from math import *
from pathlib import Path
from PIL import Image

import torch
import torch.fft as fft
import torch.nn.functional as F
import math
from torch import nn
from torch.utils.data import DataLoader
from pytorch_msssim import ssim, ms_ssim, SSIM, MS_SSIM
from scipy.ndimage import gaussian_filter
from google.colab import drive
from torch.utils.data import Dataset
from einops import rearrange

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
drive.mount('/content/drive')
# !mkdir -p /content/data
# !cp -r /content/drive/MyDrive/mri/mri_data/train/ /content/data/train
# !cp -r /content/drive/MyDrive/mri/mri_data/test/ /content/data/test
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
## DATA
train_data_path = "/content/data/train"
test_data_path = "/content/data/test"
import os

train_data_og_pair_paths = []
train_data_syn1_pair_paths = []
train_data_syn2_pair_paths = []
train_data_syn3_pair_paths = []
hq_dir = os.path.join(train_data_path, "HQ_NII_VOLUMES")
lq_dir = os.path.join(train_data_path, "LQ_NII_VOLUMES")

hq_files = sorted(os.listdir(hq_dir))
lq_files = sorted(os.listdir(lq_dir))
lq_set = set(lq_files)

for hq_file in hq_files:
    if hq_file in lq_set:
        hf = os.path.join(hq_dir, hq_file)
        lf = os.path.join(lq_dir, hq_file)
        train_data_syn3_pair_paths.append([lf, hf])

for i in range(18):
    lf_og = os.path.join(
        train_data_path,
        "low_field",
        f"sample_{i+1:03d}_lowfield.nii"
    )

    lf_syn1 = os.path.join(
        train_data_path,
        "synthetic_low_field",
        f"sample_{i+1:03d}_lowfield.nii"
    )

    lf_syn2 = os.path.join(
        train_data_path,
        "physics_nii",
        f"sample_{i+1:03d}_lowfield.nii"
    )

    hf = os.path.join(
        train_data_path,
        "high_field",
        f"sample_{i+1:03d}_highfield.nii"
    )

    train_data_og_pair_paths.append([lf_og, hf])
    train_data_syn1_pair_paths.append([lf_syn1, hf])
    train_data_syn2_pair_paths.append([lf_syn2, hf])

# for lf, hf in train_data_syn3_pair_paths:
#     print(os.path.exists(lf), os.path.exists(hf))

# %%
import os
import random

train_data_path = "/content/data/train"

# -------------------------
# Step 1: split original 18 scans
# -------------------------
scan_ids = [f"sample_{i+1:03d}" for i in range(18)]
random.seed(42)
random.shuffle(scan_ids)

train_ids = scan_ids[:15]
val_ids = scan_ids[15:17]
test_ids = scan_ids[17:18]

print("Train IDs:", train_ids)
print("Val IDs:", val_ids)
print("Test IDs:", test_ids)


# -------------------------
# Step 2: build pairs for real + syn1 + syn2
# -------------------------
def build_pairs(scan_list, use_synthetic=False):
    pairs = []
    for sid in scan_list:
        hf = os.path.join(train_data_path, "high_field", f"{sid}_highfield.nii")
        lf_real = os.path.join(train_data_path, "low_field", f"{sid}_lowfield.nii")

        if os.path.exists(lf_real):
            pairs.append([lf_real, hf])

        if use_synthetic:
            lf_syn1 = os.path.join(
                train_data_path, "synthetic_low_field", f"{sid}_lowfield.nii"
            )
            lf_syn2 = os.path.join(
                train_data_path, "physics_nii", f"{sid}_lowfield.nii"
            )

            if os.path.exists(lf_syn1):
                pairs.append([lf_syn1, hf])

            if os.path.exists(lf_syn2):
                pairs.append([lf_syn2, hf])

    return pairs


train_pairs = build_pairs(train_ids, use_synthetic=True)
val_pairs = build_pairs(val_ids, use_synthetic=False)
test_pairs = build_pairs(test_ids, use_synthetic=False)


# -------------------------
# Step 3: add syn3 pairs (400 random-named volumes)
# only to TRAIN set
# -------------------------
def build_syn3_pairs():
    pairs = []

    hq_dir = os.path.join(train_data_path, "HQ_NII_VOLUMES")
    lq_dir = os.path.join(train_data_path, "LQ_NII_VOLUMES")

    if not os.path.exists(hq_dir) or not os.path.exists(lq_dir):
        return pairs

    hq_files = sorted(os.listdir(hq_dir))
    lq_set = set(os.listdir(lq_dir))

    for hq_file in hq_files:
        if hq_file in lq_set:
            hf = os.path.join(hq_dir, hq_file)
            lf = os.path.join(lq_dir, hq_file)
            pairs.append([lf, hf])

    return pairs


syn3_pairs = build_syn3_pairs()
train_pairs += syn3_pairs


# -------------------------
# Step 4: summary
# -------------------------
print("\nDataset sizes:")
train_pairs = train_pairs[:200]
print("Train pairs:", len(train_pairs))
print("Val pairs:", len(val_pairs))
print("Test pairs:", len(test_pairs))
print("Syn3 added:", len(syn3_pairs))
# Out:
# Train IDs: ['sample_014', 'sample_013', 'sample_005', 'sample_010', 'sample_006', 'sample_008', 'sample_017', 'sample_007', 'sample_011', 'sample_016', 'sample_002', 'sample_012', 'sample_003', 'sample_015', 'sample_018']
# Val IDs: ['sample_009', 'sample_001']
# Test IDs: ['sample_004']
#
# Dataset sizes:
# Train pairs: 200
# Val pairs: 2
# Test pairs: 1
# Syn3 added: 405

# %%
print(train_pairs)
# Out:
# [['/content/data/train/low_field/sample_014_lowfield.nii', '/content/data/train/high_field/sample_014_highfield.nii'], ['/content/data/train/synthetic_low_field/sample_014_lowfield.nii', '/content/data/train/high_field/sample_014_highfield.nii'], ['/content/data/train/physics_nii/sample_014_lowfield.nii', '/content/data/train/high_field/sample_014_highfield.nii'], ['/content/data/train/low_field/sample_013_lowfield.nii', '/content/data/train/high_field/sample_013_highfield.nii'], ['/content/data/train/synthetic_low_field/sample_013_lowfield.nii', '/content/data/train/high_field/sample_013_highfield.nii'], ['/content/data/train/physics_nii/sample_013_lowfield.nii', '/content/data/train/high_field/sample_013_highfield.nii'], ['/content/data/train/low_field/sample_005_lowfield.nii', '/content/data/train/high_field/sample_005_highfield.nii'], ['/content/data/train/synthetic_low_field/sample_005_lowfield.nii', '/content/data/train/high_field/sample_005_highfield.nii'], ['/content/data/train/physics_nii/sample_005_lowfield.nii', '/content/data/train/high_field/sample_005_highfield.nii'], ['/content/data/train/low_field/sample_010_lowfield.nii', '/content/data/train/high_field/sample_010_highfield.nii'], ['/content/data/train/synthetic_low_field/sample_010_lowfield.nii', '/content/data/train/high_field/sample_010_highfield.nii'], ['/content/data/train/physics_nii/sample_010_lowfield.nii', '/content/data/train/high_field/sample_010_highfield.nii'], ['/content/data/train/low_field/sample_006_lowfield.nii', '/content/data/train/high_field/sample_006_highfield.nii'], ['/content/data/train/synthetic_low_field/sample_006_lowfield.nii', '/content/data/train/high_field/sample_006_highfield.nii'], ['/content/data/train/physics_nii/sample_006_lowfield.nii', '/content/data/train/high_field/sample_006_highfield.nii'], ['/content/data/train/low_field/sample_008_lowfield.nii', '/content/data/train/high_field/sample_008_highfield.nii'], ['/content/data/train/synthetic_low_field/sample_008_lowfield.nii', '/content/data/train/high_field/sample_008_highfield.nii'], ['/content/data/train/physics_nii/sample_008_lowfield.nii', '/content/data/train/high_field/sample_008_highfield.nii'], ['/content/data/train/low_field/sample_017_lowfield.nii', '/content/data/train/high_field/sample_017_highfield.nii'], ['/content/data/train/synthetic_low_field/sample_017_lowfield.nii', '/content/data/train/high_field/sample_017_highfield.nii'], ['/content/data/train/physics_nii/sample_017_lowfield.nii', '/content/data/train/high_field/sample_017_highfield.nii'], ['/content/data/train/low_field/sample_007_lowfield.nii', '/content/data/train/high_field/sample_007_highfield.nii'], ['/content/data/train/synthetic_low_field/sample_007_lowfield.nii', '/content/data/train/high_field/sample_007_highfield.nii'], ['/content/data/train/physics_nii/sample_007_lowfield.nii', '/content/data/train/high_field/sample_007_highfield.nii'], ['/content/data/train/low_field/sample_011_lowfield.nii', '/content/data/train/high_field/sample_011_highfield.nii'], ['/content/data/train/synthetic_low_field/sample_011_lowfield.nii', '/content/data/train/high_field/sample_011_highfield.nii'], ['/content/data/train/physics_nii/sample_011_lowfield.nii', '/content/data/train/high_field/sample_011_highfield.nii'], ['/content/data/train/low_field/sample_016_lowfield.nii', '/content/data/train/high_field/sample_016_highfield.nii'], ['/content/data/train/synthetic_low_field/sample_016_lowfield.nii', '/content/data/train/high_field/sample_016_highfield.nii'], ['/content/data/train/physics_nii/sample_016_lowfield.nii', '/content/data/train/high_field/sample_016_highfield.nii'], ['/content/data/train/low_field/sample_002_lowfield.nii', '/content/data/train/high_field/sample_002_highfield.nii'], ['/content/data/train/synthetic_low_field/sample_002_lowfield.nii', '/content/data/train/high_field/sample_002_highfield.nii'], ['/content/data/train/physics_nii/sample_002_lowfield.nii', '/content/data/train/high_field/s ...

# %%
import nibabel as nib
import numpy as np
from scipy.ndimage import zoom

def load_nii(path):
    img = nib.load(path)
    return img.get_fdata()

def normalize_mri(volume):
    volume = volume.astype(np.float32)

    # percentile-based normalization
    p1 = np.percentile(volume, 1)
    p99 = np.percentile(volume, 99)

    volume = np.clip(volume, p1, p99)
    volume = (volume - p1) / (p99 - p1 + 1e-8)

    return volume

def resample_lr_to_hr(lr_path, hr_path):
    lr_img = nib.load(lr_path)
    hr_img = nib.load(hr_path)

    lr_vol = lr_img.get_fdata()
    hr_vol = hr_img.get_fdata()

    target_shape = hr_vol.shape

    zoom_factors = [
        target_shape[0] / lr_vol.shape[0],
        target_shape[1] / lr_vol.shape[1],
        target_shape[2] / lr_vol.shape[2],
    ]

    lr_resampled = zoom(lr_vol, zoom_factors, order=3)  # cubic

    return lr_resampled, hr_vol

# %%
class MRISagittalSliceDataset(Dataset):
    def __init__(self, pair_paths):
        self.samples = []

        for lf_path, hf_path in pair_paths:
            lr_vol, hr_vol = resample_lr_to_hr(lf_path, hf_path)

            lr_vol = normalize_mri(lr_vol)
            hr_vol = normalize_mri(hr_vol)

            assert lr_vol.shape == hr_vol.shape

            # sagittal slices
            for x in range(lr_vol.shape[0]):
                self.samples.append((
                    lr_vol[x, :, :],
                    hr_vol[x, :, :]
                ))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        lr_slice, hr_slice = self.samples[idx]

        return (
            torch.from_numpy(lr_slice).float().unsqueeze(0),
            torch.from_numpy(hr_slice).float().unsqueeze(0)
        )

# %%
class Mlp(nn.Module):
    def __init__(self, in_feat, h_feat=None, out_feat=None, act_layer=nn.GELU, drop=0.):
        super().__init__()
        out_feat = out_feat or in_feat
        h_feat = h_feat or in_feat

        self.fc1 = nn.Linear(in_feat, h_feat)
        self.act = act_layer()
        self.fc2 = nn.Linear(h_feat, out_feat)
        self.drop = nn.Dropout(drop)

    def forward(self, x):
        x = self.fc1(x)
        x = self.act(x)
        x = self.drop(x)
        x = self.fc2(x)
        x = self.drop(x)
        return x

# %%
def to_3d(x):
    return rearrange(x, 'b c h w -> b (h w) c')

def to_4d(x, h, w):
    return rearrange(x, 'b (h w) c -> b c h w', h=h, w=w)


class WithBias_LayerNorm(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.weight = nn.Parameter(torch.ones(dim))
        self.bias = nn.Parameter(torch.zeros(dim))

    def forward(self, x):
        mu = x.mean(-1, keepdim=True)
        sigma = x.var(-1, keepdim=True, unbiased=False)
        return (x - mu) / torch.sqrt(sigma + 1e-5) * self.weight + self.bias


class LayerNorm(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.body = WithBias_LayerNorm(dim)

    def forward(self, x):
        h, w = x.shape[-2:]
        return to_4d(self.body(to_3d(x)), h, w)

# %%
class FeedForward(nn.Module):
    def __init__(self, dim, expansion, bias=False):
        super().__init__()
        hidden = int(dim * expansion)

        self.project_in = nn.Conv2d(dim, hidden * 2, 1, bias=bias)
        self.dwconv = nn.Conv2d(hidden * 2, hidden * 2, 3, 1, 1,
                                groups=hidden * 2, bias=bias)
        self.project_out = nn.Conv2d(hidden, dim, 1, bias=bias)

    def forward(self, x):
        x = self.project_in(x)
        x1, x2 = self.dwconv(x).chunk(2, dim=1)
        x = F.gelu(x1) * x2
        return self.project_out(x)

# %%
class Attention(nn.Module):
    def __init__(self, dim, num_heads, bias=False):
        super().__init__()
        self.num_heads = num_heads
        self.temperature = nn.Parameter(torch.ones(num_heads, 1, 1))

        self.qkv = nn.Conv2d(dim, dim * 3, 1, bias=bias)
        self.qkv_dw = nn.Conv2d(dim * 3, dim * 3, 3, 1, 1,
                                groups=dim * 3, bias=bias)
        self.project = nn.Conv2d(dim, dim, 1, bias=bias)

    def forward(self, x):
        b, c, h, w = x.shape

        qkv = self.qkv_dw(self.qkv(x))
        q, k, v = qkv.chunk(3, dim=1)

        q = rearrange(q, 'b (head c) h w -> b head c (h w)', head=self.num_heads)
        k = rearrange(k, 'b (head c) h w -> b head c (h w)', head=self.num_heads)
        v = rearrange(v, 'b (head c) h w -> b head c (h w)', head=self.num_heads)

        q = F.normalize(q, dim=-1)
        k = F.normalize(k, dim=-1)

        attn = (q @ k.transpose(-2, -1)) * self.temperature
        attn = attn.softmax(dim=-1)

        out = attn @ v
        out = rearrange(out, 'b head c (h w) -> b (head c) h w',
                        head=self.num_heads, h=h, w=w)

        return self.project(out)

# %%
class TransformerBlock(nn.Module):
    def __init__(self, dim, heads, expansion):
        super().__init__()
        self.norm1 = LayerNorm(dim)
        self.attn = Attention(dim, heads)
        self.norm2 = LayerNorm(dim)
        self.ffn = FeedForward(dim, expansion)

    def forward(self, x):
        x = x + self.attn(self.norm1(x))
        x = x + self.ffn(self.norm2(x))
        return x

# %%
class OverlapPatchEmbed(nn.Module):
    def __init__(self, in_c, embed_dim):
        super().__init__()
        self.proj = nn.Conv2d(in_c, embed_dim, 3, 1, 1)

    def forward(self, x):
        return self.proj(x)

# %%
class Downsample(nn.Module):
    def __init__(self, c):
        super().__init__()
        self.body = nn.Sequential(
            nn.Conv2d(c, c // 2, 3, 1, 1),
            nn.PixelUnshuffle(2)
        )

    def forward(self, x):
        return self.body(x)


class Upsample(nn.Module):
    def __init__(self, c):
        super().__init__()
        self.body = nn.Sequential(
            nn.Conv2d(c, c * 2, 3, 1, 1),
            nn.PixelShuffle(2)
        )

    def forward(self, x):
        return self.body(x)

# %%
class AMIR(nn.Module):
    def __init__(
        self,
        inp_channels=1,
        out_channels=1,
        dim=48,
        num_blocks=[4, 6, 6, 8],
        heads=[1, 2, 4, 8],
        expansion=2.66
    ):
        super().__init__()

        self.patch_embed = OverlapPatchEmbed(inp_channels, dim)

        # Encoder
        self.enc1 = nn.Sequential(
            *[TransformerBlock(dim, heads[0], expansion)
              for _ in range(num_blocks[0])]
        )

        self.down1 = Downsample(dim)

        self.enc2 = nn.Sequential(
            *[TransformerBlock(dim * 2, heads[1], expansion)
              for _ in range(num_blocks[1])]
        )

        self.down2 = Downsample(dim * 2)

        self.enc3 = nn.Sequential(
            *[TransformerBlock(dim * 4, heads[2], expansion)
              for _ in range(num_blocks[2])]
        )

        self.down3 = Downsample(dim * 4)

        self.latent = nn.Sequential(
            *[TransformerBlock(dim * 8, heads[3], expansion)
              for _ in range(num_blocks[3])]
        )

        # Decoder
        self.up3 = Upsample(dim * 8)
        self.dec3 = TransformerBlock(dim * 4, heads[2], expansion)

        self.up2 = Upsample(dim * 4)
        self.dec2 = TransformerBlock(dim * 2, heads[1], expansion)

        self.up1 = Upsample(dim * 2)
        self.dec1 = TransformerBlock(dim, heads[0], expansion)

        self.output = nn.Conv2d(dim, out_channels, 3, 1, 1)

    def forward(self, x):
        inp = x

        x1 = self.patch_embed(x)
        x1 = self.enc1(x1)

        x2 = self.down1(x1)
        x2 = self.enc2(x2)

        x3 = self.down2(x2)
        x3 = self.enc3(x3)

        x4 = self.down3(x3)
        x4 = self.latent(x4)

        x = self.up3(x4) + x3
        x = self.dec3(x)

        x = self.up2(x) + x2
        x = self.dec2(x)

        x = self.up1(x) + x1
        x = self.dec1(x)

        out = self.output(x) + inp
        return out

# %%
class CharbonnierLoss(nn.Module):
    def __init__(self, epsilon=1e-3):
        super().__init__()
        self.eps2 = epsilon * epsilon

    def forward(self, pred, target):
        diff = pred - target
        loss = torch.sqrt(diff * diff + self.eps2)
        return loss.mean()

def sobel_edges(x):
    sobel_x = torch.tensor(
        [[[-1,0,1],[-2,0,2],[-1,0,1]]],
        dtype=torch.float32,
        device=x.device
    ).unsqueeze(1)

    sobel_y = torch.tensor(
        [[[-1,-2,-1],[0,0,0],[1,2,1]]],
        dtype=torch.float32,
        device=x.device
    ).unsqueeze(1)

    gx = F.conv2d(x, sobel_x, padding=1)
    gy = F.conv2d(x, sobel_y, padding=1)

    return torch.sqrt(gx**2 + gy**2 + 1e-6)


class EdgeAwareLoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.l1 = nn.L1Loss()

    def forward(self, pred, target):
        return self.l1(sobel_edges(pred), sobel_edges(target))

charb = CharbonnierLoss()
edge = EdgeAwareLoss()

def total_loss(pred, target):
    return charb(pred, target) + 0.1 * edge(pred, target)

# %%
def compute_psnr(pred, target):
    mse = torch.mean((pred - target) ** 2)
    if mse == 0:
        return 100
    return 10 * math.log10(1.0 / mse.item())

# %%
model = AMIR(
    inp_channels=1,
    out_channels=1,
    dim=48
).to(device)

optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=5e-5,
    weight_decay=1e-4
)

scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer,
    T_max=100
)

# %%
import os

def train_model(model, train_loader, val_loader, epochs, save_dir):
    os.makedirs(save_dir, exist_ok=True)

    best_psnr = 0

    for epoch in range(epochs):
        # -------------------------
        # Training
        # -------------------------
        model.train()
        train_loss = 0

        for lr, hr in train_loader:
            lr = lr.to(device)
            hr = hr.to(device)

            pred = model(lr)
            loss = total_loss(pred, hr)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item()

        train_loss /= len(train_loader)

        # -------------------------
        # Validation
        # -------------------------
        model.eval()
        val_psnr = 0

        with torch.no_grad():
            for lr, hr in val_loader:
                lr = lr.to(device)
                hr = hr.to(device)

                pred = model(lr)
                val_psnr += compute_psnr(pred, hr)

        val_psnr /= len(val_loader)

        scheduler.step()

        print(f"Epoch {epoch+1}/{epochs}")
        print(f"Train Loss: {train_loss:.4f}")
        print(f"Val PSNR: {val_psnr:.2f} dB\n")

        # -------------------------
        # Save best model
        # -------------------------
        if val_psnr > best_psnr:
            best_psnr = val_psnr
            torch.save(
                model.state_dict(),
                os.path.join(save_dir, "best_model.pth")
            )
            print("Saved best model.")

# %%
train_dataset = MRISagittalSliceDataset(train_pairs)
val_dataset = MRISagittalSliceDataset(val_pairs)

print("Train samples:", len(train_dataset))
print("Val samples:", len(val_dataset))
# Out:
# Train samples: 35800
# Val samples: 358

# %%
train_loader = DataLoader(
    train_dataset,
    batch_size=4,
    shuffle=True,
    num_workers=2,
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=4,
    shuffle=False,
    num_workers=2,
    pin_memory=True
)

# %%
import torch.nn.functional as F

def pad_to_multiple(x, multiple=8):
    """
    x: tensor [B, C, H, W]
    """
    B, C, H, W = x.shape

    pad_h = (multiple - H % multiple) % multiple
    pad_w = (multiple - W % multiple) % multiple

    x = F.pad(x, (0, pad_w, 0, pad_h), mode="reflect")
    return x

# %%
lr, hr = next(iter(train_loader))
lr = lr.cuda()

lr = pad_to_multiple(lr)

out = model(lr)

print("Input:", lr.shape)
print("Output:", out.shape)
# Out:
# Input: torch.Size([4, 1, 224, 200])
# Output: torch.Size([4, 1, 224, 200])

# %%
def train_model(model, train_loader, val_loader, epochs, save_dir, resume=True):
    import os
    os.makedirs(save_dir, exist_ok=True)

    checkpoint_path = os.path.join(save_dir, "checkpoint.pth")
    best_model_path = os.path.join(save_dir, "best_model.pth")

    start_epoch = 0
    best_psnr = 0

    # -------------------------
    # Resume from checkpoint
    # -------------------------
    if resume and os.path.exists(checkpoint_path):
        print("Loading checkpoint...")
        checkpoint = torch.load(checkpoint_path, map_location=device)

        model.load_state_dict(checkpoint["model"])
        optimizer.load_state_dict(checkpoint["optimizer"])
        scheduler.load_state_dict(checkpoint["scheduler"])

        start_epoch = checkpoint["epoch"] + 1
        best_psnr = checkpoint["best_psnr"]
    else:
        print(f"Resumed from epoch {start_epoch}, best PSNR {best_psnr:.2f}")


    # -------------------------
    # Training loop
    # -------------------------
    for epoch in range(start_epoch, epochs):

        # -------------------------
        # Training
        # -------------------------
        model.train()
        train_loss = 0

        for i, (lr, hr) in enumerate(train_loader):
            lr = lr.to(device)
            hr = hr.to(device)

            lr = pad_to_multiple(lr)
            hr = pad_to_multiple(hr)

            pred = model(lr)
            loss = total_loss(pred, hr)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            if i % 100 == 0:
              print(f"Epoch {epoch+1} | Batch {i}/{len(train_loader)} | Loss {loss.item():.4f}")

        train_loss /= len(train_loader)

        # -------------------------
        # Validation
        # -------------------------
        model.eval()
        val_psnr = 0

        with torch.no_grad():
            for lr, hr in val_loader:
                lr = lr.to(device)
                hr = hr.to(device)

                lr = pad_to_multiple(lr)
                hr = pad_to_multiple(hr)

                pred = model(lr)
                val_psnr += compute_psnr(pred, hr)

        val_psnr /= len(val_loader)

        scheduler.step()

        print(f"Epoch {epoch+1}/{epochs}")
        print(f"Train Loss: {train_loss:.4f}")
        print(f"Val PSNR: {val_psnr:.2f} dB\n")

        # -------------------------
        # Save checkpoint (every epoch)
        # -------------------------
        if (epoch + 1) % 1 == 0:
            torch.save({
                "epoch": epoch,
                "model": model.state_dict(),
                "optimizer": optimizer.state_dict(),
                "scheduler": scheduler.state_dict(),
                "best_psnr": best_psnr
            }, checkpoint_path)
            print(f"Checkpoint saved at epoch {epoch+1}")

        # -------------------------
        # Save best model
        # -------------------------
        if val_psnr > best_psnr:
            best_psnr = val_psnr
            torch.save(model.state_dict(), best_model_path)
            print("Saved best model.")

# %%
def count_params(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print("Trainable params:", count_params(model))
# Out:
# Trainable params: 22250212

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
save_dir = "/content/drive/MyDrive/amir_checkpoints_v2"
os.makedirs(save_dir, exist_ok=True)
train_model(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    epochs=60,
    save_dir=save_dir,
    resume=True
)
# Out:
# Loading checkpoint...
# Epoch 25 | Batch 0/8950 | Loss 0.0277
# Epoch 25 | Batch 100/8950 | Loss 0.0238
# Epoch 25 | Batch 200/8950 | Loss 0.0120
# Epoch 25 | Batch 300/8950 | Loss 0.0121
# Epoch 25 | Batch 400/8950 | Loss 0.0169
# Epoch 25 | Batch 500/8950 | Loss 0.0147
# Epoch 25 | Batch 600/8950 | Loss 0.0308
# Epoch 25 | Batch 700/8950 | Loss 0.0205
# Epoch 25 | Batch 800/8950 | Loss 0.0333
# Epoch 25 | Batch 900/8950 | Loss 0.0275
# Epoch 25 | Batch 1000/8950 | Loss 0.0381
# Epoch 25 | Batch 1100/8950 | Loss 0.0291
# Epoch 25 | Batch 1200/8950 | Loss 0.0195
# Epoch 25 | Batch 1300/8950 | Loss 0.0329
# Epoch 25 | Batch 1400/8950 | Loss 0.0146
# Epoch 25 | Batch 1500/8950 | Loss 0.0376
# Epoch 25 | Batch 1600/8950 | Loss 0.0116
# Epoch 25 | Batch 1700/8950 | Loss 0.0220
# Epoch 25 | Batch 1800/8950 | Loss 0.0272
# Epoch 25 | Batch 1900/8950 | Loss 0.0171
# Epoch 25 | Batch 2000/8950 | Loss 0.0164
# Epoch 25 | Batch 2100/8950 | Loss 0.0203
# Epoch 25 | Batch 2200/8950 | Loss 0.0256
# Epoch 25 | Batch 2300/8950 | Loss 0.0051
# Epoch 25 | Batch 2400/8950 | Loss 0.0172
# Epoch 25 | Batch 2500/8950 | Loss 0.0275
# Epoch 25 | Batch 2600/8950 | Loss 0.0197
# Epoch 25 | Batch 2700/8950 | Loss 0.0238
# Epoch 25 | Batch 2800/8950 | Loss 0.0341
# Epoch 25 | Batch 2900/8950 | Loss 0.0111
# Epoch 25 | Batch 3000/8950 | Loss 0.0197
# Epoch 25 | Batch 3100/8950 | Loss 0.0421
# Epoch 25 | Batch 3200/8950 | Loss 0.0320
# Epoch 25 | Batch 3300/8950 | Loss 0.0318
# Epoch 25 | Batch 3400/8950 | Loss 0.0055
# Epoch 25 | Batch 3500/8950 | Loss 0.0254
# Epoch 25 | Batch 3600/8950 | Loss 0.0303
# Epoch 25 | Batch 3700/8950 | Loss 0.0272
# Epoch 25 | Batch 3800/8950 | Loss 0.0372
# Epoch 25 | Batch 3900/8950 | Loss 0.0200
# Epoch 25 | Batch 4000/8950 | Loss 0.0331
# Epoch 25 | Batch 4100/8950 | Loss 0.0281
# Epoch 25 | Batch 4200/8950 | Loss 0.0196
# Epoch 25 | Batch 4300/8950 | Loss 0.0232
# Epoch 25 | Batch 4400/8950 | Loss 0.0293
# Epoch 25 | Batch 4500/8950 | Loss 0.0205
# Epoch 25 | Batch 4600/8950 | Loss 0.0208
# Epoch 25 | Batch 4700/8950 | Loss 0.0168
# Epoch 25 | Batch 4800/8950 | Loss 0.0272
# Epoch 25 | Batch 4900/8950 | Loss 0.0248
# Epoch 25 | Batch 5000/8950 | Loss 0.0234
# Epoch 25 | Batch 5100/8950 | Loss 0.0149
# Epoch 25 | Batch 5200/8950 | Loss 0.0122
# Epoch 25 | Batch 5300/8950 | Loss 0.0273
# Epoch 25 | Batch 5400/8950 | Loss 0.0236
# Epoch 25 | Batch 5500/8950 | Loss 0.0319
# Epoch 25 | Batch 5600/8950 | Loss 0.0314
# Epoch 25 | Batch 5700/8950 | Loss 0.0236
# Epoch 25 | Batch 5800/8950 | Loss 0.0207
# Epoch 25 | Batch 5900/8950 | Loss 0.0282
# Epoch 25 | Batch 6000/8950 | Loss 0.0402
# Epoch 25 | Batch 6100/8950 | Loss 0.0128
# Epoch 25 | Batch 6200/8950 | Loss 0.0270
# Epoch 25 | Batch 6300/8950 | Loss 0.0505
# Epoch 25 | Batch 6400/8950 | Loss 0.0129
# Epoch 25 | Batch 6500/8950 | Loss 0.0266
# Epoch 25 | Batch 6600/8950 | Loss 0.0276
# Epoch 25 | Batch 6700/8950 | Loss 0.0220
# Epoch 25 | Batch 6800/8950 | Loss 0.0404
# Epoch 25 | Batch 6900/8950 | Loss 0.0146
# Epoch 25 | Batch 7000/8950 | Loss 0.0073
# Epoch 25 | Batch 7100/8950 | Loss 0.0235
# Epoch 25 | Batch 7200/8950 | Loss 0.0237
# Epoch 25 | Batch 7300/8950 | Loss 0.0079
# Epoch 25 | Batch 7400/8950 | Loss 0.0206
# Epoch 25 | Batch 7500/8950 | Loss 0.0098
# Epoch 25 | Batch 7600/8950 | Loss 0.0200
# Epoch 25 | Batch 7700/8950 | Loss 0.0214
# Epoch 25 | Batch 7800/8950 | Loss 0.0243
# Epoch 25 | Batch 7900/8950 | Loss 0.0169
# Epoch 25 | Batch 8000/8950 | Loss 0.0148
# Epoch 25 | Batch 8100/8950 | Loss 0.0227
# Epoch 25 | Batch 8200/8950 | Loss 0.0371
# Epoch 25 | Batch 8300/8950 | Loss 0.0231
# Epoch 25 | Batch 8400/8950 | Loss 0.0191
# Epoch 25 | Batch 8500/8950 | Loss 0.0122
# Epoch 25 | Batch 8600/8950 | Loss 0.0256
# Epoch 25 | Batch 8700/8950 | Loss 0.0427
# Epoch 25 | Batch 8800/8950 | Loss 0.0095
# Epoch 25 | Batch 8900/8950 | Loss 0.0310
# Epoch 25/60
# Train Loss: 0.0244
# Val PSNR: 16.76 dB
#
# Checkpoint saved at epoch 25
# Epoch 26 | Batch 0/8950 | Loss 0.0114
# Epoch 26 | Batch 100/8950 | Loss 0.0202
# Epoch 26 | Batch 200/8950 | Loss 0.0260
# Epoch 26 | Batch 300/8950 | Loss 0.0065
# Epoch 26 | Batch 400/8950 | Loss 0.0261
# Epoch 26 | Batch 500/8950 | Loss 0.0156
# Epoch 26 | Batch 600/8950 | Loss 0.0319
# Epoch 26 | Batch 700/8950 | Loss 0.0176
# Epoch 26 | Batch 800/8950 | Loss 0.0227
# Epoch 26 | Batch 900/8950 | Loss 0.0395
# Epoch 26 | Batch 1000/8950 | Loss 0.0240
# Epoch 26 | Batch 1100/8950 | Loss 0.0327
# Epoch 26 | Batch 1200/8950 | Loss 0.0129
# Epoch 26 | Batch 1300/8950 | Loss 0.0173
# Epoch 26 | Batch 1400/8950 | Loss 0.0352
# Epoch 26 | Batch 1500/8950 | Loss 0.0416
# Epoch 26 | Batch 1600/8950 | Loss 0.0269
# Epoch 26 | Batch 1700/8950 | Loss 0.0366
# Epoch 26 | Batch 1800/8950 | Loss 0.0371
# Epoch 26 | Batch 1900/8950 | Loss 0.0334
# Epoch 26 | Batch 2000/8950 | Loss 0.0322
# Epoch 26 | Batch 2100/8950 | Loss 0.0218
# Epoch 26 | Batch 2200/8950 | Loss 0.0255
# Epoch 26 | Batch 2300/8950 | Loss 0.0197
# Epoch 26 | Batch 2400/8950 | Loss 0.0255
# Epoch 26 | Batch 2500/8950 | Loss 0.0364
# Epoch 26 | Batch 2600/8950 | Loss 0.0198
# Epoch 26 | Batch 2700/8950 | Loss 0.0354
# Epoch 26 | Batch 2800/8950 | Loss 0.0123
# Epoch 26 | Batch 2900/8950 | Loss 0.0280
# Epoch 26 | Batch 3000/8950 | Loss 0.0215
# Epoch 26 | Batch 3100/8950 | Loss 0.0210
# Epoch 26 | Batch 3200/8950 | Loss 0.0105
# Epoch 26 | Batch 3300/8950 | Loss 0.0255
# Epoch 26 | Batch 3400/8950 | Loss 0.0115
# Epoch 26 | Batch 3500/8950 | Loss 0.0178
# Epoch 26 | Batch 3600/8950 | Loss 0.0197
# Epoch 26 | Batch 3700/8950 | Loss 0.0211
# Epoch 26 | Batch 3800/8950 | Loss 0.0199
# Epoch 26 | Batch 3900/8950 | Loss 0.0122
# Epoch 26 | Batch 4000/8950 | Loss 0.0356
# Epoch 26 | Batch 4100/8950 | Loss 0.0394
# Epoch 26 | Batch 4200/8950 | Loss 0.0118
# Epoch 26 | Batch 4300/8950 | Loss 0.0266
# Epoch 26 | Batch 4400/8950 | Loss 0.0211
# Epoch 26 | Batch 4500/8950 | Loss 0.0316
# Epoch 26 | Batch 4600/8950 | Loss 0.0298
# Epoch 26 | Batch 4700/8950 | Loss 0.0252
# Epoch 26 | Batch 4800/8950 | Loss 0.0364
# Epoch 26 | Batch 4900/8950 | Loss 0.0281
# Epoch 26 | Batch 5000/8950 | Loss 0.0224
# Epoch 26 | Batch 5100/8950 | Loss 0.0197
# Epoch 26 | Batch 5200/8950 | Loss 0.0316
# Epoch 26 | Batch 5300/8950 | Loss 0.0236
# Epoch 26 | Batch 5400/8950 | Loss 0.0249
# Epoch 26 | Batch 5500/8950 | Loss 0.0093
# Epoch 26 | Batch 5600/8950 | Loss 0.0330
# Epoch 26 | Batch 5700/8950 | Loss 0.0125
# Epoch 26 | Batch 5800/8950 | Loss 0.0235
# Epoch 26 | Batch 5900/8950 | Loss 0.0430
# Epoch 26 | Batch 6000/8950 | Loss 0.0131
# Epoch 26 | Batch 6100/8950 | Loss 0.0294
# Epoch 26 | Batch 6200/8950 | Loss 0.0227
# Epoch 26 | Batch 6300/8950 | Loss 0.0228
# Epoch 26 | Batch 6400/8950 | Loss 0.0154
# Epoch 26 | Batch 6500/8950 | Loss 0.0224
# Epoch 26 | Batch 6600/8950 | Loss 0.0252
# Epoch 26 | Batch 6700/8950 | Loss 0.0094
# Epoch 26 | Batch 6800/8950 | Loss 0.0283
# Epoch 26 | Batch 6900/8950 | Loss 0.0119
# Epoch 26 | Batch 7000/8950 | Loss 0.0265
# Epoch 26 | Batch 7100/8950 | Loss 0.0286
# Epoch 26 | Batch 7200/8950 | Loss 0.0256
# Epoch 26 | Batch 7300/8950 | Loss 0.0221
# Epoch 26 | Batch 7400/8950 | Loss 0.0213
# Epoch 26 | Batch 7500/8950 | Loss 0.0144
# Epoch 26 | Batch 7600/8950 | Loss 0.0237
# Epoch 26 | Batch 7700/8950 | Loss 0.0159
# Epoch 26 | Batch 7800/8950 | Loss 0.0332
# Epoch 26 | Batch 7900/8950 | Loss 0.0136
# Epoch 26 | Batch 8000/8950 | Loss 0.0163
# Epoch 26 | Batch 8100/8950 | Loss 0.0232
# Epoch 26 | Batch 8200/8950 | Loss 0.0176
# Epoch 26 | Batch 8300/8950 | Loss 0.0256
# Epoch 26 | Batch 8400/8950 | Loss 0.0206
# Epoch 26 | Batch 8500/8950 | Loss 0.0388
# Epoch 26 | Batch 8600/8950 | Loss 0.0235
# Epoch 26 | Batch 8700/8950 | Loss 0.0274
# Epoch 26 | Batch 8800/8950 | Loss 0.0252
# Epoch 26 | Batch 8900/8950 | Loss 0.0270
# Epoch 26/60
# Train Loss: 0.0242
# Val PSNR: 16.86 dB
#
# Checkpoint saved at epoch 26
# Epoch 27 | Batch 0/8950 | Loss 0.0149
# Epoch 27 | Batch 100/8950 | Loss 0.0395
# Epoch 27 | Batch 200/8950 | Loss 0.0201
# Epoch 27 | Batch 300/8950 | Loss 0.0048
# Epoch 27 | Batch 400/8950 | Loss 0.0290
# Epoch 27 | Batch 500/8950 | Loss 0.0302
# Epoch 27 | Batch 600/8950 | Loss 0.0286
# Epoch 27 | Batch 700/8950 | Loss 0.0249
# Epoch 27 | Batch 800/8950 | Loss 0.0145
# Epoch 27 | Batch 900/8950 | Loss 0.0286
# Epoch 27 | Batch 1000/8950 | Loss 0.0150
# Epoch 27 | Batch 1100/8950 | Loss 0.0190
# Epoch 27 | Batch 1200/8950 | Loss 0.0235
# Epoch 27 | Batch 1300/8950 | Loss 0.0194
# Epoch 27 | Batch 1400/8950 | Loss 0.0288
# Epoch 27 | Batch 1500/8950 | Loss 0.0286
# Epoch 27 | Batch 1600/8950 | Loss 0.0241
# Epoch 27 | Batch 1700/8950 | Loss 0.0145
# Epoch 27 | Batch 1800/8950 | Loss 0.0258
# Epoch 27 | Batch 1900/8950 | Loss 0.0128
# Epoch 27 | Batch 2000/8950 | Loss 0.0149
# Epoch 27 | Batch 2100/8950 | Loss 0.0262
# Epoch 27 | Batch 2200/8950 | Loss 0.0331
# Epoch 27 | Batch 2300/8950 | Loss 0.0364
# Epoch 27 | Batch 2400/8950 | Loss 0.0318
# Epoch 27 | Batch 2500/8950 | Loss 0.0295
# Epoch 27 | Batch 2600/8950 | Loss 0.0337
# Epoch 27 | Batch 2700/8950 | Loss 0.0109
# Epoch 27 | Batch 2800/8950 | Loss 0.0172
# Epoch 27 | Batch 2900/8950 | Loss 0.0257
# Epoch 27 | Batch 3000/8950 | Loss 0.0075
# Epoch 27 | Batch 3100/8950 | Loss 0.0177
# Epoch 27 | Batch 3200/8950 | Loss 0.0247
# Epoch 27 | Batch 3300/8950 | Loss 0.0251
# Epoch 27 | Batch 3400/8950 | Loss 0.0115
# Epoch 27 | Batch 3500/8950 | Loss 0.0187
# Epoch 27 | Batch 3600/8950 | Loss 0.0159
# Epoch 27 | Batch 3700/8950 | Loss 0.0270
# Epoch 27 | Batch 3800/8950 | Loss 0.0261
# Epoch 27 | Batch 3900/8950 | Loss 0.0326
# Epoch 27 | Batch 4000/8950 | Loss 0.0279
# Epoch 27 | Batch 4100/8950 | Loss 0.0165
# Epoch 27 | Batch 4200/8950 | Loss 0.0293
# Epoch 27 | Batch 4300/8950 | Loss 0.0182
# Epoch 27 | Batch 4400/8950 | Loss 0.0225
# Epoch 27 | Batch 4500/8950 | Loss 0.0192
# Epoch 27 | Batch 4600/8950 | Loss 0.0232
# Epoch 27 | Batch 4700/8950 | Loss 0.0193
# Epoch 27 | Batch 4800/8950 | Loss 0.0288
# Epoch 27 | Batch 4900/8950 | Loss 0.0204
# Epoch 27 | Batch 5000/8950 | Loss 0.0300
# Epoch 27 | Batch 5100/8950 | Loss 0.0392
# Epoch 27 | Batch 5200/8950 | Loss 0.0368
# Epoch 27 | Batch 5300/8950 | Loss 0.0179
# Epoch 27 | Batch 5400/8950 | Loss 0.0224
# Epoch 27 | Batch 5500/8950 | Loss 0.0161
# Epoch 27 | Batch 5600/8950 | Loss 0.0241
# Epoch 27 | Batch 5700/8950 | Loss 0.0243
# Epoch 27 | Batch 5800/8950 | Loss 0.0320
# Epoch 27 | Batch 5900/8950 | Loss 0.0326
# Epoch 27 | Batch 6000/8950 | Loss 0.0123
# Epoch 27 | Batch 6100/8950 | Loss 0.0393
# Epoch 27 | Batch 6200/8950 | Loss 0.0151
# Epoch 27 | Batch 6300/8950 | Loss 0.0240
# Epoch 27 | Batch 6400/8950 | Loss 0.0278
# Epoch 27 | Batch 6500/8950 | Loss 0.0206
# Epoch 27 | Batch 6600/8950 | Loss 0.0403
# Epoch 27 | Batch 6700/8950 | Loss 0.0342
# Epoch 27 | Batch 6800/8950 | Loss 0.0229
# Epoch 27 | Batch 6900/8950 | Loss 0.0236
# Epoch 27 | Batch 7000/8950 | Loss 0.0295
# Epoch 27 | Batch 7100/8950 | Loss 0.0156
# Epoch 27 | Batch 7200/8950 | Loss 0.0285
# Epoch 27 | Batch 7300/8950 | Loss 0.0227
# Epoch 27 | Batch 7400/8950 | Loss 0.0154
# Epoch 27 | Batch 7500/8950 | Loss 0.0206
# Epoch 27 | Batch 7600/8950 | Loss 0.0341
# Epoch 27 | Batch 7700/8950 | Loss 0.0051
# Epoch 27 | Batch 7800/8950 | Loss 0.0346
# Epoch 27 | Batch 7900/8950 | Loss 0.0146
# Epoch 27 | Batch 8000/8950 | Loss 0.0332
# Epoch 27 | Batch 8100/8950 | Loss 0.0244
# Epoch 27 | Batch 8200/8950 | Loss 0.0258
# Epoch 27 | Batch 8300/8950 | Loss 0.0195
# Epoch 27 | Batch 8400/8950 | Loss 0.0223
# Epoch 27 | Batch 8500/8950 | Loss 0.0239
# Epoch 27 | Batch 8600/8950 | Loss 0.0170
# Epoch 27 | Batch 8700/8950 | Loss 0.0244
# Epoch 27 | Batch 8800/8950 | Loss 0.0107
# Epoch 27 | Batch 8900/8950 | Loss 0.0234
# Epoch 27/60
# Train Loss: 0.0240
# Val PSNR: 16.74 dB
#
# Checkpoint saved at epoch 27
# Epoch 28 | Batch 0/8950 | Loss 0.0168
# Epoch 28 | Batch 100/8950 | Loss 0.0250
# Epoch 28 | Batch 200/8950 | Loss 0.0291
# Epoch 28 | Batch 300/8950 | Loss 0.0189
# Epoch 28 | Batch 400/8950 | Loss 0.0271
# Epoch 28 | Batch 500/8950 | Loss 0.0238
# Epoch 28 | Batch 600/8950 | Loss 0.0234
# Epoch 28 | Batch 700/8950 | Loss 0.0086
# Epoch 28 | Batch 800/8950 | Loss 0.0339
# Epoch 28 | Batch 900/8950 | Loss 0.0238
# Epoch 28 | Batch 1000/8950 | Loss 0.0140
# Epoch 28 | Batch 1100/8950 | Loss 0.0277
# Epoch 28 | Batch 1200/8950 | Loss 0.0289
# Epoch 28 | Batch 1300/8950 | Loss 0.0216
# Epoch 28 | Batch 1400/8950 | Loss 0.0229
# Epoch 28 | Batch 1500/8950 | Loss 0.0195
# Epoch 28 | Batch 1600/8950 | Loss 0.0174
# Epoch 28 | Batch 1700/8950 | Loss 0.0255
# Epoch 28 | Batch 1800/8950 | Loss 0.0334
# Epoch 28 | Batch 1900/8950 | Loss 0.0298
# Epoch 28 | Batch 2000/8950 | Loss 0.0218
# Epoch 28 | Batch 2100/8950 | Loss 0.0294
# Epoch 28 | Batch 2200/8950 | Loss 0.0230
# Epoch 28 | Batch 2300/8950 | Loss 0.0294
# Epoch 28 | Batch 2400/8950 | Loss 0.0065
# Epoch 28 | Batch 2500/8950 | Loss 0.0170
# Epoch 28 | Batch 2600/8950 | Loss 0.0196
# Epoch 28 | Batch 2700/8950 | Loss 0.0243
# Epoch 28 | Batch 2800/8950 | Loss 0.0203
# Epoch 28 | Batch 2900/8950 | Loss 0.0375
# Epoch 28 | Batch 3000/8950 | Loss 0.0304
# Epoch 28 | Batch 3100/8950 | Loss 0.0294
# Epoch 28 | Batch 3200/8950 | Loss 0.0239
# Epoch 28 | Batch 3300/8950 | Loss 0.0195
# Epoch 28 | Batch 3400/8950 | Loss 0.0358
# Epoch 28 | Batch 3500/8950 | Loss 0.0295
# Epoch 28 | Batch 3600/8950 | Loss 0.0303
# Epoch 28 | Batch 3700/8950 | Loss 0.0058
# Epoch 28 | Batch 3800/8950 | Loss 0.0138
# Epoch 28 | Batch 3900/8950 | Loss 0.0337
# Epoch 28 | Batch 4000/8950 | Loss 0.0222
# Epoch 28 | Batch 4100/8950 | Loss 0.0202
# Epoch 28 | Batch 4200/8950 | Loss 0.0251
# Epoch 28 | Batch 4300/8950 | Loss 0.0270
# Epoch 28 | Batch 4400/8950 | Loss 0.0240
# Epoch 28 | Batch 4500/8950 | Loss 0.0281
# Epoch 28 | Batch 4600/8950 | Loss 0.0234
# Epoch 28 | Batch 4700/8950 | Loss 0.0308
# Epoch 28 | Batch 4800/8950 | Loss 0.0272
# Epoch 28 | Batch 4900/8950 | Loss 0.0103
# Epoch 28 | Batch 5000/8950 | Loss 0.0263
# Epoch 28 | Batch 5100/8950 | Loss 0.0179
# Epoch 28 | Batch 5200/8950 | Loss 0.0357
# Epoch 28 | Batch 5300/8950 | Loss 0.0252
# Epoch 28 | Batch 5400/8950 | Loss 0.0117
# Epoch 28 | Batch 5500/8950 | Loss 0.0364
# Epoch 28 | Batch 5600/8950 | Loss 0.0228
# Epoch 28 | Batch 5700/8950 | Loss 0.0267
# Epoch 28 | Batch 5800/8950 | Loss 0.0192
# Epoch 28 | Batch 5900/8950 | Loss 0.0337
# Epoch 28 | Batch 6000/8950 | Loss 0.0201
# Epoch 28 | Batch 6100/8950 | Loss 0.0169
# Epoch 28 | Batch 6200/8950 | Loss 0.0323
# Epoch 28 | Batch 6300/8950 | Loss 0.0171
# Epoch 28 | Batch 6400/8950 | Loss 0.0312
# Epoch 28 | Batch 6500/8950 | Loss 0.0231
# Epoch 28 | Batch 6600/8950 | Loss 0.0376
# Epoch 28 | Batch 6700/8950 | Loss 0.0211
# Epoch 28 | Batch 6800/8950 | Loss 0.0180
# Epoch 28 | Batch 6900/8950 | Loss 0.0194
# Epoch 28 | Batch 7000/8950 | Loss 0.0161
# Epoch 28 | Batch 7100/8950 | Loss 0.0352
# Epoch 28 | Batch 7200/8950 | Loss 0.0319
# Epoch 28 | Batch 7300/8950 | Loss 0.0339
# Epoch 28 | Batch 7400/8950 | Loss 0.0155
# Epoch 28 | Batch 7500/8950 | Loss 0.0178
# Epoch 28 | Batch 7600/8950 | Loss 0.0435
# Epoch 28 | Batch 7700/8950 | Loss 0.0163
# Epoch 28 | Batch 7800/8950 | Loss 0.0246
# Epoch 28 | Batch 7900/8950 | Loss 0.0203
# Epoch 28 | Batch 8000/8950 | Loss 0.0406
# Epoch 28 | Batch 8100/8950 | Loss 0.0393
# Epoch 28 | Batch 8200/8950 | Loss 0.0219
# Epoch 28 | Batch 8300/8950 | Loss 0.0258
# Epoch 28 | Batch 8400/8950 | Loss 0.0214
# Epoch 28 | Batch 8500/8950 | Loss 0.0278
# Epoch 28 | Batch 8600/8950 | Loss 0.0237
# Epoch 28 | Batch 8700/8950 | Loss 0.0244
# Epoch 28 | Batch 8800/8950 | Loss 0.0235
# Epoch 28 | Batch 8900/8950 | Loss 0.0204
# Epoch 28/60
# Train Loss: 0.0238
# Val PSNR: 16.86 dB
#
# Checkpoint saved at epoch 28
# Epoch 29 | Batch 0/8950 | Loss 0.0185
# Epoch 29 | Batch 100/8950 | Loss 0.0111
# Epoch 29 | Batch 200/8950 | Loss 0.0279
# Epoch 29 | Batch 300/8950 | Loss 0.0241
# Epoch 29 | Batch 400/8950 | Loss 0.0402
# Epoch 29 | Batch 500/8950 | Loss 0.0291
# Epoch 29 | Batch 600/8950 | Loss 0.0333
# Epoch 29 | Batch 700/8950 | Loss 0.0383
# Epoch 29 | Batch 800/8950 | Loss 0.0249
# Epoch 29 | Batch 900/8950 | Loss 0.0214
# Epoch 29 | Batch 1000/8950 | Loss 0.0151
# Epoch 29 | Batch 1100/8950 | Loss 0.0231
# Epoch 29 | Batch 1200/8950 | Loss 0.0334
# Epoch 29 | Batch 1300/8950 | Loss 0.0301
# Epoch 29 | Batch 1400/8950 | Loss 0.0110
# Epoch 29 | Batch 1500/8950 | Loss 0.0237
# Epoch 29 | Batch 1600/8950 | Loss 0.0209
# Epoch 29 | Batch 1700/8950 | Loss 0.0253
# Epoch 29 | Batch 1800/8950 | Loss 0.0240
# Epoch 29 | Batch 1900/8950 | Loss 0.0222
# Epoch 29 | Batch 2000/8950 | Loss 0.0395
# Epoch 29 | Batch 2100/8950 | Loss 0.0080
# Epoch 29 | Batch 2200/8950 | Loss 0.0270
# Epoch 29 | Batch 2300/8950 | Loss 0.0233
# Epoch 29 | Batch 2400/8950 | Loss 0.0279
# Epoch 29 | Batch 2500/8950 | Loss 0.0207
# Epoch 29 | Batch 2600/8950 | Loss 0.0119
# Epoch 29 | Batch 2700/8950 | Loss 0.0316
# Epoch 29 | Batch 2800/8950 | Loss 0.0309
# Epoch 29 | Batch 2900/8950 | Loss 0.0382
# Epoch 29 | Batch 3000/8950 | Loss 0.0152
# Epoch 29 | Batch 3100/8950 | Loss 0.0271
# Epoch 29 | Batch 3200/8950 | Loss 0.0213
# Epoch 29 | Batch 3300/8950 | Loss 0.0164
# Epoch 29 | Batch 3400/8950 | Loss 0.0331
# Epoch 29 | Batch 3500/8950 | Loss 0.0189
# Epoch 29 | Batch 3600/8950 | Loss 0.0312
# Epoch 29 | Batch 3700/8950 | Loss 0.0108
# Epoch 29 | Batch 3800/8950 | Loss 0.0186
# Epoch 29 | Batch 3900/8950 | Loss 0.0350
# Epoch 29 | Batch 4000/8950 | Loss 0.0332
# Epoch 29 | Batch 4100/8950 | Loss 0.0250
# Epoch 29 | Batch 4200/8950 | Loss 0.0425
# Epoch 29 | Batch 4300/8950 | Loss 0.0308
# Epoch 29 | Batch 4400/8950 | Loss 0.0251
# Epoch 29 | Batch 4500/8950 | Loss 0.0171
# Epoch 29 | Batch 4600/8950 | Loss 0.0260
# Epoch 29 | Batch 4700/8950 | Loss 0.0286
# Epoch 29 | Batch 4800/8950 | Loss 0.0284
# Epoch 29 | Batch 4900/8950 | Loss 0.0142
# Epoch 29 | Batch 5000/8950 | Loss 0.0435
# Epoch 29 | Batch 5100/8950 | Loss 0.0255
# Epoch 29 | Batch 5200/8950 | Loss 0.0219
# Epoch 29 | Batch 5300/8950 | Loss 0.0274
# Epoch 29 | Batch 5400/8950 | Loss 0.0363
# Epoch 29 | Batch 5500/8950 | Loss 0.0290
# Epoch 29 | Batch 5600/8950 | Loss 0.0241
# Epoch 29 | Batch 5700/8950 | Loss 0.0205
# Epoch 29 | Batch 5800/8950 | Loss 0.0133
# Epoch 29 | Batch 5900/8950 | Loss 0.0264
# Epoch 29 | Batch 6000/8950 | Loss 0.0250
# Epoch 29 | Batch 6100/8950 | Loss 0.0178
# Epoch 29 | Batch 6200/8950 | Loss 0.0187
# Epoch 29 | Batch 6300/8950 | Loss 0.0425
# Epoch 29 | Batch 6400/8950 | Loss 0.0203
# Epoch 29 | Batch 6500/8950 | Loss 0.0384
# Epoch 29 | Batch 6600/8950 | Loss 0.0327
# Epoch 29 | Batch 6700/8950 | Loss 0.0365
# Epoch 29 | Batch 6800/8950 | Loss 0.0216
# Epoch 29 | Batch 6900/8950 | Loss 0.0166
# Epoch 29 | Batch 7000/8950 | Loss 0.0096
# Epoch 29 | Batch 7100/8950 | Loss 0.0271
# Epoch 29 | Batch 7200/8950 | Loss 0.0129
# Epoch 29 | Batch 7300/8950 | Loss 0.0302
# Epoch 29 | Batch 7400/8950 | Loss 0.0197
# Epoch 29 | Batch 7500/8950 | Loss 0.0206
# Epoch 29 | Batch 7600/8950 | Loss 0.0305
# Epoch 29 | Batch 7700/8950 | Loss 0.0296
# Epoch 29 | Batch 7800/8950 | Loss 0.0116
# Epoch 29 | Batch 7900/8950 | Loss 0.0398
# Epoch 29 | Batch 8000/8950 | Loss 0.0176
# Epoch 29 | Batch 8100/8950 | Loss 0.0283
# Epoch 29 | Batch 8200/8950 | Loss 0.0351
# Epoch 29 | Batch 8300/8950 | Loss 0.0190
# Epoch 29 | Batch 8400/8950 | Loss 0.0254
# Epoch 29 | Batch 8500/8950 | Loss 0.0276
# Epoch 29 | Batch 8600/8950 | Loss 0.0182
# Epoch 29 | Batch 8700/8950 | Loss 0.0201
# Epoch 29 | Batch 8800/8950 | Loss 0.0143
# Epoch 29 | Batch 8900/8950 | Loss 0.0114
# Epoch 29/60
# Train Loss: 0.0236
# Val PSNR: 16.88 dB
#
# Checkpoint saved at epoch 29
# Epoch 30 | Batch 0/8950 | Loss 0.0302
# Epoch 30 | Batch 100/8950 | Loss 0.0197
# Epoch 30 | Batch 200/8950 | Loss 0.0230
# Epoch 30 | Batch 300/8950 | Loss 0.0143
# Epoch 30 | Batch 400/8950 | Loss 0.0279
# Epoch 30 | Batch 500/8950 | Loss 0.0301
# Epoch 30 | Batch 600/8950 | Loss 0.0121
# Epoch 30 | Batch 700/8950 | Loss 0.0287
# Epoch 30 | Batch 800/8950 | Loss 0.0194
# Epoch 30 | Batch 900/8950 | Loss 0.0327
# Epoch 30 | Batch 1000/8950 | Loss 0.0256
# Epoch 30 | Batch 1100/8950 | Loss 0.0332
# Epoch 30 | Batch 1200/8950 | Loss 0.0203
# Epoch 30 | Batch 1300/8950 | Loss 0.0188
# Epoch 30 | Batch 1400/8950 | Loss 0.0219
# Epoch 30 | Batch 1500/8950 | Loss 0.0187
# Epoch 30 | Batch 1600/8950 | Loss 0.0263
# Epoch 30 | Batch 1700/8950 | Loss 0.0303
# Epoch 30 | Batch 1800/8950 | Loss 0.0131
# Epoch 30 | Batch 1900/8950 | Loss 0.0296
# Epoch 30 | Batch 2000/8950 | Loss 0.0201
# Epoch 30 | Batch 2100/8950 | Loss 0.0314
# Epoch 30 | Batch 2200/8950 | Loss 0.0190
# Epoch 30 | Batch 2300/8950 | Loss 0.0315
# Epoch 30 | Batch 2400/8950 | Loss 0.0383
# Epoch 30 | Batch 2500/8950 | Loss 0.0043
# Epoch 30 | Batch 2600/8950 | Loss 0.0181
# Epoch 30 | Batch 2700/8950 | Loss 0.0286
# Epoch 30 | Batch 2800/8950 | Loss 0.0300
# Epoch 30 | Batch 2900/8950 | Loss 0.0219
# Epoch 30 | Batch 3000/8950 | Loss 0.0233
# Epoch 30 | Batch 3100/8950 | Loss 0.0289
# Epoch 30 | Batch 3200/8950 | Loss 0.0246
# Epoch 30 | Batch 3300/8950 | Loss 0.0114
# Epoch 30 | Batch 3400/8950 | Loss 0.0286
# Epoch 30 | Batch 3500/8950 | Loss 0.0333
# Epoch 30 | Batch 3600/8950 | Loss 0.0267
# Epoch 30 | Batch 3700/8950 | Loss 0.0199
# Epoch 30 | Batch 3800/8950 | Loss 0.0225
# Epoch 30 | Batch 3900/8950 | Loss 0.0234
# Epoch 30 | Batch 4000/8950 | Loss 0.0235
# Epoch 30 | Batch 4100/8950 | Loss 0.0215
# Epoch 30 | Batch 4200/8950 | Loss 0.0209
# Epoch 30 | Batch 4300/8950 | Loss 0.0407
# Epoch 30 | Batch 4400/8950 | Loss 0.0221
# Epoch 30 | Batch 4500/8950 | Loss 0.0308
# Epoch 30 | Batch 4600/8950 | Loss 0.0289
# Epoch 30 | Batch 4700/8950 | Loss 0.0211
# Epoch 30 | Batch 4800/8950 | Loss 0.0257
# Epoch 30 | Batch 4900/8950 | Loss 0.0121
# Epoch 30 | Batch 5000/8950 | Loss 0.0207
# Epoch 30 | Batch 5100/8950 | Loss 0.0103
# Epoch 30 | Batch 5200/8950 | Loss 0.0340
# Epoch 30 | Batch 5300/8950 | Loss 0.0252
# Epoch 30 | Batch 5400/8950 | Loss 0.0210
# Epoch 30 | Batch 5500/8950 | Loss 0.0319
# Epoch 30 | Batch 5600/8950 | Loss 0.0263
# Epoch 30 | Batch 5700/8950 | Loss 0.0284
# Epoch 30 | Batch 5800/8950 | Loss 0.0379
# Epoch 30 | Batch 5900/8950 | Loss 0.0191
# Epoch 30 | Batch 6000/8950 | Loss 0.0304
# Epoch 30 | Batch 6100/8950 | Loss 0.0194
# Epoch 30 | Batch 6200/8950 | Loss 0.0353
# Epoch 30 | Batch 6300/8950 | Loss 0.0344
# Epoch 30 | Batch 6400/8950 | Loss 0.0143
# Epoch 30 | Batch 6500/8950 | Loss 0.0395
# Epoch 30 | Batch 6600/8950 | Loss 0.0190
# Epoch 30 | Batch 6700/8950 | Loss 0.0244
# Epoch 30 | Batch 6800/8950 | Loss 0.0280
# Epoch 30 | Batch 6900/8950 | Loss 0.0337
# Epoch 30 | Batch 7000/8950 | Loss 0.0182
# Epoch 30 | Batch 7100/8950 | Loss 0.0464
# Epoch 30 | Batch 7200/8950 | Loss 0.0220
# Epoch 30 | Batch 7300/8950 | Loss 0.0150
# Epoch 30 | Batch 7400/8950 | Loss 0.0272
# Epoch 30 | Batch 7500/8950 | Loss 0.0332
# Epoch 30 | Batch 7600/8950 | Loss 0.0272
# Epoch 30 | Batch 7700/8950 | Loss 0.0269
# Epoch 30 | Batch 7800/8950 | Loss 0.0196
# Epoch 30 | Batch 7900/8950 | Loss 0.0358
# Epoch 30 | Batch 8000/8950 | Loss 0.0206
# Epoch 30 | Batch 8100/8950 | Loss 0.0101
# Epoch 30 | Batch 8200/8950 | Loss 0.0218
# Epoch 30 | Batch 8300/8950 | Loss 0.0227
# Epoch 30 | Batch 8400/8950 | Loss 0.0210
# Epoch 30 | Batch 8500/8950 | Loss 0.0381
# Epoch 30 | Batch 8600/8950 | Loss 0.0104
# Epoch 30 | Batch 8700/8950 | Loss 0.0303
# Epoch 30 | Batch 8800/8950 | Loss 0.0321
# Epoch 30 | Batch 8900/8950 | Loss 0.0345
# Epoch 30/60
# Train Loss: 0.0234
# Val PSNR: 16.76 dB
#
# Checkpoint saved at epoch 30
# Epoch 31 | Batch 0/8950 | Loss 0.0211
# Epoch 31 | Batch 100/8950 | Loss 0.0250
# Epoch 31 | Batch 200/8950 | Loss 0.0230
# Epoch 31 | Batch 300/8950 | Loss 0.0172
# Epoch 31 | Batch 400/8950 | Loss 0.0255
# Epoch 31 | Batch 500/8950 | Loss 0.0334
# Epoch 31 | Batch 600/8950 | Loss 0.0229
# Epoch 31 | Batch 700/8950 | Loss 0.0399
# Epoch 31 | Batch 800/8950 | Loss 0.0455
# Epoch 31 | Batch 900/8950 | Loss 0.0254
# Epoch 31 | Batch 1000/8950 | Loss 0.0263
# Epoch 31 | Batch 1100/8950 | Loss 0.0181
# Epoch 31 | Batch 1200/8950 | Loss 0.0403
# Epoch 31 | Batch 1300/8950 | Loss 0.0236
# Epoch 31 | Batch 1400/8950 | Loss 0.0192
# Epoch 31 | Batch 1500/8950 | Loss 0.0072
# Epoch 31 | Batch 1600/8950 | Loss 0.0038
# Epoch 31 | Batch 1700/8950 | Loss 0.0113
# Epoch 31 | Batch 1800/8950 | Loss 0.0228
# Epoch 31 | Batch 1900/8950 | Loss 0.0152
# Epoch 31 | Batch 2000/8950 | Loss 0.0110
# Epoch 31 | Batch 2100/8950 | Loss 0.0136
# Epoch 31 | Batch 2200/8950 | Loss 0.0223
# Epoch 31 | Batch 2300/8950 | Loss 0.0184
# Epoch 31 | Batch 2400/8950 | Loss 0.0227
# Epoch 31 | Batch 2500/8950 | Loss 0.0312
# Epoch 31 | Batch 2600/8950 | Loss 0.0284
# Epoch 31 | Batch 2700/8950 | Loss 0.0134
# Epoch 31 | Batch 2800/8950 | Loss 0.0187
# Epoch 31 | Batch 2900/8950 | Loss 0.0222
# Epoch 31 | Batch 3000/8950 | Loss 0.0216
# Epoch 31 | Batch 3100/8950 | Loss 0.0292
# Epoch 31 | Batch 3200/8950 | Loss 0.0270
# Epoch 31 | Batch 3300/8950 | Loss 0.0328
# Epoch 31 | Batch 3400/8950 | Loss 0.0211
# Epoch 31 | Batch 3500/8950 | Loss 0.0187
# Epoch 31 | Batch 3600/8950 | Loss 0.0056
# Epoch 31 | Batch 3700/8950 | Loss 0.0144
# Epoch 31 | Batch 3800/8950 | Loss 0.0312
# Epoch 31 | Batch 3900/8950 | Loss 0.0169
# Epoch 31 | Batch 4000/8950 | Loss 0.0313
# Epoch 31 | Batch 4100/8950 | Loss 0.0193
# Epoch 31 | Batch 4200/8950 | Loss 0.0217
# Epoch 31 | Batch 4300/8950 | Loss 0.0234
# Epoch 31 | Batch 4400/8950 | Loss 0.0359
# Epoch 31 | Batch 4500/8950 | Loss 0.0162
# Epoch 31 | Batch 4600/8950 | Loss 0.0251
# Epoch 31 | Batch 4700/8950 | Loss 0.0205
# Epoch 31 | Batch 4800/8950 | Loss 0.0280
# Epoch 31 | Batch 4900/8950 | Loss 0.0307
# Epoch 31 | Batch 5000/8950 | Loss 0.0165
# Epoch 31 | Batch 5100/8950 | Loss 0.0119
# Epoch 31 | Batch 5200/8950 | Loss 0.0280
# Epoch 31 | Batch 5300/8950 | Loss 0.0332
# Epoch 31 | Batch 5400/8950 | Loss 0.0229
# Epoch 31 | Batch 5500/8950 | Loss 0.0192
# Epoch 31 | Batch 5600/8950 | Loss 0.0343
# Epoch 31 | Batch 5700/8950 | Loss 0.0090
# Epoch 31 | Batch 5800/8950 | Loss 0.0203
# Epoch 31 | Batch 5900/8950 | Loss 0.0204
# Epoch 31 | Batch 6000/8950 | Loss 0.0191
# Epoch 31 | Batch 6100/8950 | Loss 0.0306
# Epoch 31 | Batch 6200/8950 | Loss 0.0376
# Epoch 31 | Batch 6300/8950 | Loss 0.0180
# Epoch 31 | Batch 6400/8950 | Loss 0.0229
# Epoch 31 | Batch 6500/8950 | Loss 0.0212
# Epoch 31 | Batch 6600/8950 | Loss 0.0256
# Epoch 31 | Batch 6700/8950 | Loss 0.0336
# Epoch 31 | Batch 6800/8950 | Loss 0.0158
# Epoch 31 | Batch 6900/8950 | Loss 0.0125
# Epoch 31 | Batch 7000/8950 | Loss 0.0263
# Epoch 31 | Batch 7100/8950 | Loss 0.0091
# Epoch 31 | Batch 7200/8950 | Loss 0.0178
# Epoch 31 | Batch 7300/8950 | Loss 0.0217
# Epoch 31 | Batch 7400/8950 | Loss 0.0338
# Epoch 31 | Batch 7500/8950 | Loss 0.0299
# Epoch 31 | Batch 7600/8950 | Loss 0.0166
# Epoch 31 | Batch 7700/8950 | Loss 0.0313
# Epoch 31 | Batch 7800/8950 | Loss 0.0180
# Epoch 31 | Batch 7900/8950 | Loss 0.0217
# Epoch 31 | Batch 8000/8950 | Loss 0.0162
# Epoch 31 | Batch 8100/8950 | Loss 0.0309
# Epoch 31 | Batch 8200/8950 | Loss 0.0175
# Epoch 31 | Batch 8300/8950 | Loss 0.0184
# Epoch 31 | Batch 8400/8950 | Loss 0.0314
# Epoch 31 | Batch 8500/8950 | Loss 0.0213
# Epoch 31 | Batch 8600/8950 | Loss 0.0210
# Epoch 31 | Batch 8700/8950 | Loss 0.0217
# Epoch 31 | Batch 8800/8950 | Loss 0.0385
# Epoch 31 | Batch 8900/8950 | Loss 0.0184
# Epoch 31/60
# Train Loss: 0.0232
# Val PSNR: 16.83 dB
#
# Checkpoint saved at epoch 31
# Epoch 32 | Batch 0/8950 | Loss 0.0310
# Epoch 32 | Batch 100/8950 | Loss 0.0338
# Epoch 32 | Batch 200/8950 | Loss 0.0135
# Epoch 32 | Batch 300/8950 | Loss 0.0234
# Epoch 32 | Batch 400/8950 | Loss 0.0306
# Epoch 32 | Batch 500/8950 | Loss 0.0151
# Epoch 32 | Batch 600/8950 | Loss 0.0402
# Epoch 32 | Batch 700/8950 | Loss 0.0220
# Epoch 32 | Batch 800/8950 | Loss 0.0310
# Epoch 32 | Batch 900/8950 | Loss 0.0221
# Epoch 32 | Batch 1000/8950 | Loss 0.0263
# Epoch 32 | Batch 1100/8950 | Loss 0.0221
# Epoch 32 | Batch 1200/8950 | Loss 0.0190
# Epoch 32 | Batch 1300/8950 | Loss 0.0104
# Epoch 32 | Batch 1400/8950 | Loss 0.0208
# Epoch 32 | Batch 1500/8950 | Loss 0.0330
# Epoch 32 | Batch 1600/8950 | Loss 0.0311
# Epoch 32 | Batch 1700/8950 | Loss 0.0230
# Epoch 32 | Batch 1800/8950 | Loss 0.0138
# Epoch 32 | Batch 1900/8950 | Loss 0.0266
# Epoch 32 | Batch 2000/8950 | Loss 0.0306
# Epoch 32 | Batch 2100/8950 | Loss 0.0263
# Epoch 32 | Batch 2200/8950 | Loss 0.0282
# Epoch 32 | Batch 2300/8950 | Loss 0.0183
# Epoch 32 | Batch 2400/8950 | Loss 0.0260
# Epoch 32 | Batch 2500/8950 | Loss 0.0115
# Epoch 32 | Batch 2600/8950 | Loss 0.0192
# Epoch 32 | Batch 2700/8950 | Loss 0.0196
# Epoch 32 | Batch 2800/8950 | Loss 0.0232
# Epoch 32 | Batch 2900/8950 | Loss 0.0193
# Epoch 32 | Batch 3000/8950 | Loss 0.0267
# Epoch 32 | Batch 3100/8950 | Loss 0.0225
# Epoch 32 | Batch 3200/8950 | Loss 0.0338
# Epoch 32 | Batch 3300/8950 | Loss 0.0295
# Epoch 32 | Batch 3400/8950 | Loss 0.0187
# Epoch 32 | Batch 3500/8950 | Loss 0.0228
# Epoch 32 | Batch 3600/8950 | Loss 0.0384
# Epoch 32 | Batch 3700/8950 | Loss 0.0174
# Epoch 32 | Batch 3800/8950 | Loss 0.0129
# Epoch 32 | Batch 3900/8950 | Loss 0.0190
# Epoch 32 | Batch 4000/8950 | Loss 0.0438
# Epoch 32 | Batch 4100/8950 | Loss 0.0374
# Epoch 32 | Batch 4200/8950 | Loss 0.0152
# Epoch 32 | Batch 4300/8950 | Loss 0.0278
# Epoch 32 | Batch 4400/8950 | Loss 0.0327
# Epoch 32 | Batch 4500/8950 | Loss 0.0310
# Epoch 32 | Batch 4600/8950 | Loss 0.0164
# Epoch 32 | Batch 4700/8950 | Loss 0.0311
# Epoch 32 | Batch 4800/8950 | Loss 0.0146
# Epoch 32 | Batch 4900/8950 | Loss 0.0185
# Epoch 32 | Batch 5000/8950 | Loss 0.0286
# Epoch 32 | Batch 5100/8950 | Loss 0.0363
# Epoch 32 | Batch 5200/8950 | Loss 0.0173
# Epoch 32 | Batch 5300/8950 | Loss 0.0291
# Epoch 32 | Batch 5400/8950 | Loss 0.0260
# Epoch 32 | Batch 5500/8950 | Loss 0.0110
# Epoch 32 | Batch 5600/8950 | Loss 0.0209
# Epoch 32 | Batch 5700/8950 | Loss 0.0096
# Epoch 32 | Batch 5800/8950 | Loss 0.0231
# Epoch 32 | Batch 5900/8950 | Loss 0.0205
# Epoch 32 | Batch 6000/8950 | Loss 0.0310
# Epoch 32 | Batch 6100/8950 | Loss 0.0236
# Epoch 32 | Batch 6200/8950 | Loss 0.0162
# Epoch 32 | Batch 6300/8950 | Loss 0.0335
# Epoch 32 | Batch 6400/8950 | Loss 0.0232
# Epoch 32 | Batch 6500/8950 | Loss 0.0131
# Epoch 32 | Batch 6600/8950 | Loss 0.0239
# Epoch 32 | Batch 6700/8950 | Loss 0.0152
# Epoch 32 | Batch 6800/8950 | Loss 0.0184
# Epoch 32 | Batch 6900/8950 | Loss 0.0187
# Epoch 32 | Batch 7000/8950 | Loss 0.0310
# Epoch 32 | Batch 7100/8950 | Loss 0.0165
# Epoch 32 | Batch 7200/8950 | Loss 0.0249
# Epoch 32 | Batch 7300/8950 | Loss 0.0087
# Epoch 32 | Batch 7400/8950 | Loss 0.0133
# Epoch 32 | Batch 7500/8950 | Loss 0.0201
# Epoch 32 | Batch 7600/8950 | Loss 0.0180
# Epoch 32 | Batch 7700/8950 | Loss 0.0236
# Epoch 32 | Batch 7800/8950 | Loss 0.0209
# Epoch 32 | Batch 7900/8950 | Loss 0.0188
# Epoch 32 | Batch 8000/8950 | Loss 0.0294
# Epoch 32 | Batch 8100/8950 | Loss 0.0090
# Epoch 32 | Batch 8200/8950 | Loss 0.0346
# Epoch 32 | Batch 8300/8950 | Loss 0.0223
# Epoch 32 | Batch 8400/8950 | Loss 0.0238
# Epoch 32 | Batch 8500/8950 | Loss 0.0192
# Epoch 32 | Batch 8600/8950 | Loss 0.0235
# Epoch 32 | Batch 8700/8950 | Loss 0.0186
# Epoch 32 | Batch 8800/8950 | Loss 0.0260
# Epoch 32 | Batch 8900/8950 | Loss 0.0108
# Epoch 32/60
# Train Loss: 0.0230
# Val PSNR: 16.80 dB
#
# Checkpoint saved at epoch 32
# Epoch 33 | Batch 0/8950 | Loss 0.0233
# Epoch 33 | Batch 100/8950 | Loss 0.0053
# Epoch 33 | Batch 200/8950 | Loss 0.0144
# Epoch 33 | Batch 300/8950 | Loss 0.0107
# Epoch 33 | Batch 400/8950 | Loss 0.0208
# Epoch 33 | Batch 500/8950 | Loss 0.0213
# Epoch 33 | Batch 600/8950 | Loss 0.0312
# Epoch 33 | Batch 700/8950 | Loss 0.0077
# Epoch 33 | Batch 800/8950 | Loss 0.0288
# Epoch 33 | Batch 900/8950 | Loss 0.0276
# Epoch 33 | Batch 1000/8950 | Loss 0.0309
# Epoch 33 | Batch 1100/8950 | Loss 0.0128
# Epoch 33 | Batch 1200/8950 | Loss 0.0296
# Epoch 33 | Batch 1300/8950 | Loss 0.0271
# Epoch 33 | Batch 1400/8950 | Loss 0.0164
# Epoch 33 | Batch 1500/8950 | Loss 0.0042
# Epoch 33 | Batch 1600/8950 | Loss 0.0292
# Epoch 33 | Batch 1700/8950 | Loss 0.0233
# Epoch 33 | Batch 1800/8950 | Loss 0.0159
# Epoch 33 | Batch 1900/8950 | Loss 0.0418
# Epoch 33 | Batch 2000/8950 | Loss 0.0230
# Epoch 33 | Batch 2100/8950 | Loss 0.0250
# Epoch 33 | Batch 2200/8950 | Loss 0.0312
# Epoch 33 | Batch 2300/8950 | Loss 0.0316
# Epoch 33 | Batch 2400/8950 | Loss 0.0201
# Epoch 33 | Batch 2500/8950 | Loss 0.0172
# Epoch 33 | Batch 2600/8950 | Loss 0.0229
# Epoch 33 | Batch 2700/8950 | Loss 0.0204
# Epoch 33 | Batch 2800/8950 | Loss 0.0236
# Epoch 33 | Batch 2900/8950 | Loss 0.0217
# Epoch 33 | Batch 3000/8950 | Loss 0.0125
# Epoch 33 | Batch 3100/8950 | Loss 0.0204
# Epoch 33 | Batch 3200/8950 | Loss 0.0164
# Epoch 33 | Batch 3300/8950 | Loss 0.0202
# Epoch 33 | Batch 3400/8950 | Loss 0.0194
# Epoch 33 | Batch 3500/8950 | Loss 0.0174
# Epoch 33 | Batch 3600/8950 | Loss 0.0188
# Epoch 33 | Batch 3700/8950 | Loss 0.0130
# Epoch 33 | Batch 3800/8950 | Loss 0.0320
# Epoch 33 | Batch 3900/8950 | Loss 0.0155
# Epoch 33 | Batch 4000/8950 | Loss 0.0324
# Epoch 33 | Batch 4100/8950 | Loss 0.0203
# Epoch 33 | Batch 4200/8950 | Loss 0.0326
# Epoch 33 | Batch 4300/8950 | Loss 0.0118
# Epoch 33 | Batch 4400/8950 | Loss 0.0298
# Epoch 33 | Batch 4500/8950 | Loss 0.0151
# Epoch 33 | Batch 4600/8950 | Loss 0.0216
# Epoch 33 | Batch 4700/8950 | Loss 0.0220
# Epoch 33 | Batch 4800/8950 | Loss 0.0273
# Epoch 33 | Batch 4900/8950 | Loss 0.0238
# Epoch 33 | Batch 5000/8950 | Loss 0.0181
# Epoch 33 | Batch 5100/8950 | Loss 0.0207
# Epoch 33 | Batch 5200/8950 | Loss 0.0211
# Epoch 33 | Batch 5300/8950 | Loss 0.0146
# Epoch 33 | Batch 5400/8950 | Loss 0.0188
# Epoch 33 | Batch 5500/8950 | Loss 0.0324
# Epoch 33 | Batch 5600/8950 | Loss 0.0131
# Epoch 33 | Batch 5700/8950 | Loss 0.0223
# Epoch 33 | Batch 5800/8950 | Loss 0.0362
# Epoch 33 | Batch 5900/8950 | Loss 0.0387
# Epoch 33 | Batch 6000/8950 | Loss 0.0358
# Epoch 33 | Batch 6100/8950 | Loss 0.0200
# Epoch 33 | Batch 6200/8950 | Loss 0.0330
# Epoch 33 | Batch 6300/8950 | Loss 0.0110
# Epoch 33 | Batch 6400/8950 | Loss 0.0161
# Epoch 33 | Batch 6500/8950 | Loss 0.0196
# Epoch 33 | Batch 6600/8950 | Loss 0.0172
# Epoch 33 | Batch 6700/8950 | Loss 0.0172
# Epoch 33 | Batch 6800/8950 | Loss 0.0316
# Epoch 33 | Batch 6900/8950 | Loss 0.0255
# Epoch 33 | Batch 7000/8950 | Loss 0.0239
# Epoch 33 | Batch 7100/8950 | Loss 0.0227
# Epoch 33 | Batch 7200/8950 | Loss 0.0151
# Epoch 33 | Batch 7300/8950 | Loss 0.0114
# Epoch 33 | Batch 7400/8950 | Loss 0.0136
# Epoch 33 | Batch 7500/8950 | Loss 0.0256
# Epoch 33 | Batch 7600/8950 | Loss 0.0113
# Epoch 33 | Batch 7700/8950 | Loss 0.0114
# Epoch 33 | Batch 7800/8950 | Loss 0.0288
# Epoch 33 | Batch 7900/8950 | Loss 0.0303
# Epoch 33 | Batch 8000/8950 | Loss 0.0122
# Epoch 33 | Batch 8100/8950 | Loss 0.0343
# Epoch 33 | Batch 8200/8950 | Loss 0.0063
# Epoch 33 | Batch 8300/8950 | Loss 0.0143
# Epoch 33 | Batch 8400/8950 | Loss 0.0160
# Epoch 33 | Batch 8500/8950 | Loss 0.0199
# Epoch 33 | Batch 8600/8950 | Loss 0.0213
# Epoch 33 | Batch 8700/8950 | Loss 0.0250
# Epoch 33 | Batch 8800/8950 | Loss 0.0333
# Epoch 33 | Batch 8900/8950 | Loss 0.0224
# Epoch 33/60
# Train Loss: 0.0229
# Val PSNR: 16.79 dB
#
# Checkpoint saved at epoch 33
# Epoch 34 | Batch 0/8950 | Loss 0.0235
# Epoch 34 | Batch 100/8950 | Loss 0.0238
# Epoch 34 | Batch 200/8950 | Loss 0.0165
# Epoch 34 | Batch 300/8950 | Loss 0.0230
# Epoch 34 | Batch 400/8950 | Loss 0.0299
# Epoch 34 | Batch 500/8950 | Loss 0.0174
# Epoch 34 | Batch 600/8950 | Loss 0.0281
# Epoch 34 | Batch 700/8950 | Loss 0.0195
# Epoch 34 | Batch 800/8950 | Loss 0.0283
# Epoch 34 | Batch 900/8950 | Loss 0.0365
# Epoch 34 | Batch 1000/8950 | Loss 0.0104
# Epoch 34 | Batch 1100/8950 | Loss 0.0215
# Epoch 34 | Batch 1200/8950 | Loss 0.0299
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-4165944113.py in <cell line: 0>()
#       1 save_dir = "/content/drive/MyDrive/amir_checkpoints_v2"
#       2 os.makedirs(save_dir, exist_ok=True)
# ----> 3 train_model(
#       4     model=model,
#       5     train_loader=train_loader,
#
# /tmp/ipython-input-2879511361.py in train_model(model, train_loader, val_loader, epochs, save_dir, resume)
#      49             optimizer.zero_grad()
#      50             loss.backward()
# ---> 51             optimizer.step()
#      52
#      53             train_loss += loss.item()
#
# /usr/local/lib/python3.12/dist-packages/torch/optim/lr_scheduler.py in wrapper(*args, **kwargs)
#     131                     opt = opt_ref()
#     132                     opt._opt_called = True  # type: ignore[union-attr]
# --> 133                     return func.__get__(opt, opt.__class__)(*args, **kwargs)
#     134
#     135                 wrapper._wrapped_by_lr_sched = True  # type: ignore[attr-defined]
#
# /usr/local/lib/python3.12/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     515                             )
#     516
# --> 517                 out = func(*args, **kwargs)
#     518                 self._optimizer_step_code()
#     519
#
# /usr/local/lib/python3.12/dist-packages/torch/optim/optimizer.py in _use_grad(*args, **kwargs)
#      80             torch.set_grad_enabled(self.defaults["differentiable"])
#      81             torch._dynamo.graph_break()
# ---> 82             ret = func(*args, **kwargs)
#      83         finally:
#      84             torch._dynamo.graph_break()
#
# /usr/local/lib/python3.12/dist-packages/torch/optim/adam.py in step(self, closure)
#     245             )
#     246
# --> 247             adam(
#     248                 params_with_grad,
#     249                 grads,
#
# /usr/local/lib/python3.12/dist-packages/torch/optim/optimizer.py in maybe_fallback(*args, **kwargs)
#     148                 return disabled_func(*args, **kwargs)
#     149             else:
# --> 150                 return func(*args, **kwargs)
#     151
#     152         return maybe_fallback
#
# /usr/local/lib/python3.12/dist-packages/torch/optim/adam.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, decoupled_weight_decay, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     951         func = _single_tensor_adam
#     952
# --> 953     func(
#     954         params,
#     955         grads,
#
# /usr/local/lib/python3.12/dist-packages/torch/optim/adam.py in _multi_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, decoupled_weight_decay)
#     757         else:
#     758             bias_correction1 = [
# --> 759                 1 - beta1 ** _get_value(step) for step in device_state_steps
#     760             ]
#     761             bias_correction2 = [
#
# /usr/local/lib/python3.12/dist-packages/torch/optim/optimizer.py in _get_value(x)
#      95         return x
#      96     else:
# ---> 97         return x.item() if isinstance(x, torch.Tensor) else x
#      98
#      99
#
# KeyboardInterrupt:

# %%
import torch.nn.functional as F

def pad_to_multiple(x, multiple=2):
    _, _, h, w = x.shape
    pad_h = (multiple - h % multiple) % multiple
    pad_w = (multiple - w % multiple) % multiple

    x = F.pad(x, (0, pad_w, 0, pad_h))
    return x, pad_h, pad_w

def remove_padding(x, pad_h, pad_w):
    if pad_h > 0:
        x = x[..., :-pad_h, :]
    if pad_w > 0:
        x = x[..., :, :-pad_w]
    return x

# %%
import torch.nn.functional as F

model.eval()

lr, hr = val_dataset[0]
lr = lr.unsqueeze(0).to(device)

print("Original shape:", lr.shape)

# FORCE pad to multiple of 8 (safe for AMIR)
_, _, h, w = lr.shape
pad_h = (8 - h % 8) % 8
pad_w = (8 - w % 8) % 8

lr = F.pad(lr, (0, pad_w, 0, pad_h))

print("After padding:", lr.shape)

with torch.no_grad():
    sr = model(lr)
# Out:
# Original shape: torch.Size([1, 1, 221, 200])
# After padding: torch.Size([1, 1, 224, 200])

# %%
# move tensors to CPU and convert to numpy
lr = lr.detach().cpu().squeeze().numpy()
sr = sr.detach().cpu().squeeze().numpy()
hr = hr.detach().cpu().squeeze().numpy()

import matplotlib.pyplot as plt

plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
plt.imshow(lr, cmap="gray")
plt.title("LR")

plt.subplot(1,3,2)
plt.imshow(sr, cmap="gray")
plt.title("SR")

plt.subplot(1,3,3)
plt.imshow(hr, cmap="gray")
plt.title("HR")

plt.show()

# %%
import numpy as np
import torch.nn.functional as F

model.eval()

lf_path, hf_path = val_pairs[1]
lr_vol, hr_vol = resample_lr_to_hr(lf_path, hf_path)
lr_vol = normalize_mri(lr_vol)

sr_slices = []

with torch.no_grad():
    for x in range(lr_vol.shape[0]):
        lr_slice = lr_vol[x]

        lr_tensor = (
            torch.from_numpy(lr_slice)
            .float()
            .unsqueeze(0)
            .unsqueeze(0)
            .to(device)
        )

        # ---- FORCE padding to multiple of 8 ----
        _, _, h, w = lr_tensor.shape
        pad_h = (8 - h % 8) % 8
        pad_w = (8 - w % 8) % 8

        lr_tensor = F.pad(lr_tensor, (0, pad_w, 0, pad_h))

        # verify padding
        # print("Padded shape:", lr_tensor.shape)

        sr_tensor = model(lr_tensor)

        # remove padding
        if pad_h > 0:
            sr_tensor = sr_tensor[..., :-pad_h, :]
        if pad_w > 0:
            sr_tensor = sr_tensor[..., :, :-pad_w]

        sr_slice = sr_tensor.cpu().squeeze().numpy()
        sr_slices.append(sr_slice)

sr_vol = np.stack(sr_slices, axis=0)

# %%
import nibabel as nib

hr_nii = nib.load(hf_path)
affine = hr_nii.affine

sr_nii = nib.Nifti1Image(sr_vol, affine)
nib.save(sr_nii, "sr_output.nii")

print("Saved sr_output.nii")
# Out:
# Saved sr_output.nii

# %%
sr_loaded = nib.load("sr_output.nii").get_fdata()

slice_idx = sr_loaded.shape[0] // 2

plt.imshow(sr_loaded[slice_idx], cmap="gray")
plt.title("SR middle slice")
plt.show()

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load SR
sr_loaded = nib.load("sr_output.nii").get_fdata()

# Load LR and HR
lr_loaded = nib.load(lf_path).get_fdata()
hr_loaded = nib.load(hf_path).get_fdata()

# %%
slice_idx = sr_loaded.shape[0] // 2

# %%
# get aligned volumes
lr_vol, hr_vol = resample_lr_to_hr(lf_path, hf_path)
lr_vol = normalize_mri(lr_vol)

sr_loaded = nib.load("sr_output.nii").get_fdata()

slice_idx = sr_loaded.shape[0] // 2

plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
plt.imshow(lr_vol[slice_idx], cmap="gray")
plt.title("LR (aligned)")

plt.subplot(1,3,2)
plt.imshow(sr_loaded[slice_idx], cmap="gray")
plt.title("SR")

plt.subplot(1,3,3)
plt.imshow(hr_vol[slice_idx], cmap="gray")
plt.title("HR")

plt.show()

# %%
import matplotlib.pyplot as plt
import random

# pick a random training sample
idx = random.randint(0, len(train_dataset) - 1)
print("Sample index:", idx)

lr, hr = train_dataset[idx]

# convert to numpy
lr = lr.squeeze().numpy()
hr = hr.squeeze().numpy()

plt.figure(figsize=(8,4))

plt.subplot(1,2,1)
plt.imshow(lr, cmap="gray")
plt.title("LR (training sample)")

plt.subplot(1,2,2)
plt.imshow(hr, cmap="gray")
plt.title("HR (training sample)")

plt.show()

# %%
import numpy as np
import torch.nn.functional as F

model.eval()

_, hf_path = val_pairs[1]
lf_path = '/content/data/test/low_field/sample_019_lowfield.nii'
lr_vol, hr_vol = resample_lr_to_hr(lf_path, hf_path)
lr_vol = normalize_mri(lr_vol)

sr_slices = []

with torch.no_grad():
    for x in range(lr_vol.shape[0]):
        lr_slice = lr_vol[x]

        lr_tensor = (
            torch.from_numpy(lr_slice)
            .float()
            .unsqueeze(0)
            .unsqueeze(0)
            .to(device)
        )

        # ---- FORCE padding to multiple of 8 ----
        _, _, h, w = lr_tensor.shape
        pad_h = (8 - h % 8) % 8
        pad_w = (8 - w % 8) % 8

        lr_tensor = F.pad(lr_tensor, (0, pad_w, 0, pad_h))

        # verify padding
        # print("Padded shape:", lr_tensor.shape)

        sr_tensor = model(lr_tensor)

        # remove padding
        if pad_h > 0:
            sr_tensor = sr_tensor[..., :-pad_h, :]
        if pad_w > 0:
            sr_tensor = sr_tensor[..., :, :-pad_w]

        sr_slice = sr_tensor.cpu().squeeze().numpy()
        sr_slices.append(sr_slice)

sr_vol = np.stack(sr_slices, axis=0)

hr_nii = nib.load(hf_path)
affine = hr_nii.affine

sr_nii = nib.Nifti1Image(sr_vol, affine)
nib.save(sr_nii, "sample_019.nii")

print("sample_019_highfield.nii")
# Out:
# sample_019_highfield.nii

# %%
"""
Slice Extraction Utility for Low-Field to High-Field MRI Super-Resolution

This script provides standardized functions for:
1. Extracting all 200 axial slices from a 3D MRI volume
2. Encoding slices to base64 for CSV submission
3. Decoding base64 back to numpy arrays
4. Creating submission rows in the correct format

IMPORTANT: Use these functions to ensure your submissions match the expected format!

Submission format:
  - Each row represents one slice
  - row_id format: "sample_XXX_slice_YYY" (e.g., "sample_019_slice_100")
  - prediction: base64-encoded 2D slice (179 x 221 pixels)
"""

import numpy as np
import nibabel as nib
import base64
import io
import pandas as pd

# All 200 slices are used
NUM_SLICES = 200


def load_nifti(path):
    """
    Load a NIfTI file and return the data array.

    Args:
        path: Path to .nii.gz file

    Returns:
        3D numpy array (x, y, z)
    """
    img = nib.load(path)
    return img.get_fdata()


def slice_to_base64(slice_2d):
    """
    Encode a 2D slice to base64 string for CSV submission.

    The slice is normalized to uint8 (0-255) and compressed.
    Original value range is stored to allow reconstruction.

    Args:
        slice_2d: 2D numpy array

    Returns:
        Base64 encoded string
    """
    slice_min = float(slice_2d.min())
    slice_max = float(slice_2d.max())

    if slice_max - slice_min > 0:
        normalized = ((slice_2d - slice_min) / (slice_max - slice_min) * 255).astype(np.uint8)
    else:
        normalized = np.zeros_like(slice_2d, dtype=np.uint8)

    buffer = io.BytesIO()
    np.savez_compressed(buffer,
                        slice=normalized,
                        shape=np.array(slice_2d.shape),
                        min_val=np.array([slice_min]),
                        max_val=np.array([slice_max]))
    buffer.seek(0)

    return base64.b64encode(buffer.read()).decode('utf-8')


def base64_to_slice(b64_string):
    """
    Decode a base64 string back to a 2D numpy array.

    Args:
        b64_string: Base64 encoded string from slice_to_base64

    Returns:
        2D numpy array (float32)
    """
    buffer = io.BytesIO(base64.b64decode(b64_string))
    data = np.load(buffer)

    normalized = data['slice']
    min_val_arr = data['min_val']
    max_val_arr = data['max_val']

    # Handle both scalar and array storage formats
    min_val = float(min_val_arr.item()) if min_val_arr.ndim > 0 else float(min_val_arr)
    max_val = float(max_val_arr.item()) if max_val_arr.ndim > 0 else float(max_val_arr)

    if max_val - min_val > 0:
        original = normalized.astype(np.float32) / 255 * (max_val - min_val) + min_val
    else:
        original = np.zeros_like(normalized, dtype=np.float32)

    return original


def volume_to_submission_rows(volume, sample_id):
    """
    Convert a 3D volume to submission rows.

    Extracts all 200 axial slices and encodes them to base64.

    Args:
        volume: 3D numpy array with shape (179, 221, 200)
        sample_id: Sample identifier (e.g., "sample_019")

    Returns:
        List of dictionaries with keys: row_id, prediction
    """
    if volume.shape[2] != NUM_SLICES:
        raise ValueError(f"Volume must have {NUM_SLICES} slices in z-dimension, got {volume.shape[2]}")

    rows = []
    for slice_idx in range(NUM_SLICES):
        row_id = f"{sample_id}_slice_{slice_idx:03d}"
        slice_2d = volume[:, :, slice_idx]
        b64 = slice_to_base64(slice_2d)
        rows.append({"row_id": row_id, "prediction": b64})

    return rows


def create_submission_df(predictions_dict):
    """
    Create a submission DataFrame from a dictionary of predictions.

    Args:
        predictions_dict: Dictionary mapping sample_id to 3D volume
                         e.g., {"sample_019": volume_019, "sample_020": volume_020, ...}

    Returns:
        pandas DataFrame ready for submission
    """
    all_rows = []
    for sample_id, volume in predictions_dict.items():
        rows = volume_to_submission_rows(volume, sample_id)
        all_rows.extend(rows)

    return pd.DataFrame(all_rows)


def nifti_to_submission_rows(nifti_path, sample_id):
    """
    Load a NIfTI file and convert to submission rows.

    Args:
        nifti_path: Path to .nii.gz file
        sample_id: Sample identifier (e.g., "sample_019")

    Returns:
        List of dictionaries with keys: row_id, prediction
    """
    volume = load_nifti(nifti_path)
    return volume_to_submission_rows(volume, sample_id)

data = []
for row in range(5):
    id = 19 + row
    x = nifti_to_submission_rows(f"./sample_0{id:02d}.nii", f"sample_0{id:02d}")
    data.extend(x)
df = pd.DataFrame(data)
df.to_csv("submission_AMIR.csv", index=False)

# %%
# Load SR
sr_loaded = nib.load("sample_019_highfield.nii").get_fdata()

# Load LR and HR
lr_loaded = nib.load(lf_path).get_fdata()
hr_loaded = nib.load(hf_path).get_fdata()
slice_idx = sr_loaded.shape[0] // 2
# get aligned volumes
lr_vol, hr_vol = resample_lr_to_hr(lf_path, hf_path)
lr_vol = normalize_mri(lr_vol)

sr_loaded = nib.load("sample_019_highfield.nii").get_fdata()

slice_idx = sr_loaded.shape[0] // 2

plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
plt.imshow(lr_vol[slice_idx], cmap="gray")
plt.title("LR (aligned)")

plt.subplot(1,3,2)
plt.imshow(sr_loaded[slice_idx], cmap="gray")
plt.title("SR")

plt.subplot(1,3,3)
plt.imshow(hr_vol[slice_idx], cmap="gray")
plt.title("HR")

plt.show()
